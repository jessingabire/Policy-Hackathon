# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('median-household-income-town-2019.csv')

# %%
df.head()
# Out:
#       Town       FIPS       Year                           Race/Ethnicity  \
# 0  Andover  901301080  2005-2009                                      All
# 1  Andover  901301080  2005-2009                                      All
# 2  Andover  901301080  2005-2009                                      All
# 3  Andover  901301080  2005-2009                                      All
# 4  Andover  901301080  2005-2009  American Indian and Alaska Native Alone
#
#             Measure Type                 Variable     Value
# 0                 Number  Median Household Income  84757.00
# 1                 Number         Margins of Error   9003.00
# 2  Ratio to State Median  Median Household Income      1.25
# 3  Ratio to State Median         Margins of Error      0.13
# 4                 Number  Median Household Income  -9999.00

# %%
MHI=df['Variable']=='Median Household Income'

# %%
df=df[MHI]

# %%
value= df['Measure Type']=='Number'
df=df[value]

# %%
df.describe()
# Out:
#                FIPS          Value
# count  1.870000e+04   18700.000000
# mean   8.954655e+08   46889.537701
# std    6.888520e+07   56306.797561
# min    9.000000e+00   -9999.000000
# 25%    9.003521e+08   -9999.000000
# 50%    9.007224e+08   50046.500000
# 75%    9.011424e+08   84893.250000
# max    9.015882e+08  250001.000000

# %%
df.head(10)
# Out:
#        Town       FIPS       Year                              Race/Ethnicity  \
# 0   Andover  901301080  2005-2009                                         All
# 4   Andover  901301080  2005-2009     American Indian and Alaska Native Alone
# 8   Andover  901301080  2005-2009                                 Asian Alone
# 12  Andover  901301080  2005-2009             Black or African American Alone
# 16  Andover  901301080  2005-2009                          Hispanic or Latino
# 20  Andover  901301080  2005-2009  Native Hawaiian and Other Pacific Islander
# 24  Andover  901301080  2005-2009                       Some Other Race Alone
# 28  Andover  901301080  2005-2009                           Two or More Races
# 32  Andover  901301080  2005-2009                                 White Alone
# 36  Andover  901301080  2005-2009          White Alone Not Hispanic or Latino
#
#    Measure Type                 Variable     Value
# 0        Number  Median Household Income   84757.0
# ...

# %%
##Categories within Race/ethnicity
###
by_race = df.groupby(["Town","Race/Ethnicity"])['Value'].mean()
by_race.unstack().plot(figsize=(30,10))
plt.xticks(rotation=50)
plt.show()

# %%
all_df = df

# %%
df_all= df['Race/Ethnicity']=='All'
all_df = all_df[df_all]

# %%
##Datasets with Median Household Income Value for all race/ethnicity
all_df
# Out:
#             Town       FIPS       Year Race/Ethnicity Measure Type  \
# 0        Andover  901301080  2005-2009            All       Number
# 40       Andover  901301080  2006-2010            All       Number
# 80       Andover  901301080  2007-2011            All       Number
# 120      Andover  901301080  2008-2012            All       Number
# 160      Andover  901301080  2009-2013            All       Number
# ...          ...        ...        ...            ...          ...
# 74600  Woodstock  901588190  2011-2015            All       Number
# 74640  Woodstock  901588190  2012-2016            All       Number
# 74680  Woodstock  901588190  2013-2017            All       Number
# 74720  Woodstock  901588190  2014-2018            All       Number
# 74760  Woodstock  901588190  2015-2019            All       Number
#
#                       Variable    Value
# 0      Median Household Income  84757.0
# 40     Median Household Income  84274.0
# ...

# %%
##Group by Town and mean MHI 

town = all_df.groupby(['Town'])['Value'].mean()
# Out:
# 0        84757.0
# 40       84274.0
# 80       91406.0
# 120      97762.0
# 160      88438.0
#           ...
# 74600    78594.0
# 74640    84700.0
# 74680    81441.0
# 74720    89531.0
# 74760    86821.0
# Length: 1870, dtype: float64

# %%
##Sorting by MHI for all in ascending order

MHI_sort_all = all_df.sort_values(by='Value',ascending=True)
MHI_sort_all
# Out:
#            Town       FIPS       Year Race/Ethnicity Measure Type  \
# 28280  Hartford  900337070  2008-2012            All       Number
# 28200  Hartford  900337070  2006-2010            All       Number
# 28240  Hartford  900337070  2007-2011            All       Number
# 28160  Hartford  900337070  2005-2009            All       Number
# 28360  Hartford  900337070  2010-2014            All       Number
# ...         ...        ...        ...            ...          ...
# 69360    Weston  900183430  2012-2016            All       Number
# 69440    Weston  900183430  2014-2018            All       Number
# 69400    Weston  900183430  2013-2017            All       Number
# 69480    Weston  900183430  2015-2019            All       Number
# 15800    Darien  900118850  2015-2019            All       Number
#
#                       Variable     Value
# 28280  Median Household Income   28931.0
# 28200  Median Household Income   28970.0
# 28240  Median Household Income   29107.0
# ...

# %%
##Sorting by MHI for all

MHI_sort = df.sort_values(by='Value',ascending=True)

non_values = MHI_sort[ MHI_sort['Value'] == (-9999) ].index
MHI_sort.drop(non_values,inplace = True)

# %%
MHI_sort
# Out:
#                 Town       FIPS       Year  \
# 25644       Griswold  901133900  2008-2012
# 48588     Plainville  900360120  2009-2013
# 59048       Stafford  901372090  2007-2011
# 18564  East Hartford  900322630  2007-2011
# 11492        Clinton  900715350  2006-2010
# ...              ...        ...        ...
# 56256        Sherman  900168310  2014-2018
# 71208         Wilton  900186370  2014-2018
# 63816          Union  901377830  2005-2009
# 7180         Bristol  900308490  2008-2012
# 6888     Bridgewater  900508210  2012-2016
#
#                                    Race/Ethnicity Measure Type  \
# 25644     American Indian and Alaska Native Alone       Number
# 48588                           Two or More Races       Number
# 59048                                 Asian Alone       Number
# 18564     American Indian and Alaska Native Alone       Number
# 11492             Black or African American Alone       Number
# ...

# %%
##New dataset for all Household income from 20015-2019

by_date_all = all_df['Year']=='2015-2019'
by_date_all=all_df[by_date_all]

# %%
by_date_all
# Out:
#                 Town       FIPS       Year Race/Ethnicity Measure Type  \
# 400          Andover  901301080  2015-2019            All       Number
# 840          Ansonia  900901220  2015-2019            All       Number
# 1280         Ashford  901501430  2015-2019            All       Number
# 1720            Avon  900302060  2015-2019            All       Number
# 2160     Barkhamsted  900502760  2015-2019            All       Number
# ...              ...        ...        ...            ...          ...
# 73000  Windsor Locks  900387070  2015-2019            All       Number
# 73440        Wolcott  900987560  2015-2019            All       Number
# 73880     Woodbridge  900987700  2015-2019            All       Number
# 74320       Woodbury  900587910  2015-2019            All       Number
# 74760      Woodstock  901588190  2015-2019            All       Number
#
#                       Variable     Value
# 400    Median Household Income  105328.0
# ...

# %%
##New dataset for all households income including race
by_date = df['Year']=='2015-2019'
by_date=df[by_date]

# %%
by_date
# Out:
#             Town       FIPS       Year  \
# 400      Andover  901301080  2015-2019
# 404      Andover  901301080  2015-2019
# 408      Andover  901301080  2015-2019
# 412      Andover  901301080  2015-2019
# 416      Andover  901301080  2015-2019
# ...          ...        ...        ...
# 74780  Woodstock  901588190  2015-2019
# 74784  Woodstock  901588190  2015-2019
# 74788  Woodstock  901588190  2015-2019
# 74792  Woodstock  901588190  2015-2019
# 74796  Woodstock  901588190  2015-2019
#
#                                    Race/Ethnicity Measure Type  \
# 400                                           All       Number
# 404       American Indian and Alaska Native Alone       Number
# 408                                   Asian Alone       Number
# 412               Black or African American Alone       Number
# 416                            Hispanic or Latino       Number
# ...                                           ...          ...
# ...

# %%
##Analysing income values for this time period

by_date_all.sort_values(by='Value',ascending=True)
# Out:
#               Town       FIPS       Year Race/Ethnicity Measure Type  \
# 28560     Hartford  900337070  2015-2019            All       Number
# 41320    New Haven  900952070  2015-2019            All       Number
# 66840    Waterbury  900980070  2015-2019            All       Number
# 41760   New London  901152350  2015-2019            All       Number
# 39560  New Britain  900350440  2015-2019            All       Number
# ...            ...        ...        ...            ...          ...
# 40000   New Canaan  900150580  2015-2019            All       Number
# 71240       Wilton  900186370  2015-2019            All       Number
# 69920     Westport  900183500  2015-2019            All       Number
# 69480       Weston  900183430  2015-2019            All       Number
# 15800       Darien  900118850  2015-2019            All       Number
#
#                       Variable     Value
# 28560  Median Household Income   36278.0
# 41320  Median Household Income   42222.0
# ...

# %%
by_date.sort_values(by='Value',ascending=True)
non_values1 = by_date[ by_date['Value'] == (-9999) ].index
by_date.drop(non_values1,inplace = True)
by_date.sort_values(by='Value',ascending=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#              Town       FIPS       Year  \
# 16704       Derby  900919550  2015-2019
# 28564    Hartford  900337070  2015-2019
# 55844     Shelton  900168170  2015-2019
# 7444      Bristol  900308490  2015-2019
# 41772  New London  901152350  2015-2019
# ...           ...        ...        ...
# 25488   Greenwich  900133620  2015-2019
# 69488      Weston  900183430  2015-2019
# 29888      Hebron  901337910  2015-2019
# 15808      Darien  900118850  2015-2019
# 71248      Wilton  900186370  2015-2019
#
#                                 Race/Ethnicity Measure Type  \
# 16704                    Some Other Race Alone       Number
# ...

# %%
by_date_all
# Out:
#                 Town       FIPS       Year Race/Ethnicity Measure Type  \
# 400          Andover  901301080  2015-2019            All       Number
# 840          Ansonia  900901220  2015-2019            All       Number
# 1280         Ashford  901501430  2015-2019            All       Number
# 1720            Avon  900302060  2015-2019            All       Number
# 2160     Barkhamsted  900502760  2015-2019            All       Number
# ...              ...        ...        ...            ...          ...
# 73000  Windsor Locks  900387070  2015-2019            All       Number
# 73440        Wolcott  900987560  2015-2019            All       Number
# 73880     Woodbridge  900987700  2015-2019            All       Number
# 74320       Woodbury  900587910  2015-2019            All       Number
# 74760      Woodstock  901588190  2015-2019            All       Number
#
#                       Variable     Value
# 400    Median Household Income  105328.0
# ...

# %% [markdown]
# # Housing Counts, Energy Cost, Energy Burden in 2018

# %%
##Energy Cost 

df_encost = pd.read_csv('Avg Annual Energy Cost.csv')

# %%
df_encost
# Out:
#     Geography ID           Name  Avg. Annual Energy Cost
# 0       '901080'        Andover                     3700
# 1       '901220'        Ansonia                     3447
# 2       '901430'        Ashford                     3529
# 3       '902060'           Avon                     4068
# 4       '902760'    Barkhamsted                     4119
# ..           ...            ...                      ...
# 164     '987070'  Windsor Locks                     3116
# 165     '987560'        Wolcott                     4430
# 166     '987700'     Woodbridge                     4879
# 167     '987910'       Woodbury                     4029
# 168     '988190'      Woodstock                     3666
#
# [169 rows x 3 columns]

# %%
housing = pd.read_csv('Housing Counts.csv')
housing.head()
housing.max(axis=0)
# Out:
# Geography ID       '988190'
#  Name             Woodstock
# Housing Counts        50547
# dtype: object

# %%
df_enburden = pd.read_csv("Avg Energy Burden.csv")

# %%
##Dataframe focusing on the 10 towns with the highest poer outages

h_encost= pd.merge(housing,df_encost)
h_cost_burden = pd.merge(h_encost,df_enburden)

# %%
##DataFrame with the housing counts, energy cost and energy burden in 2018 by town
h_cost_burden
# Out:
#     Geography ID           Name  Housing Counts  Avg. Annual Energy Cost  \
# 0       '901080'        Andover            1235                     3700
# 1       '901220'        Ansonia            7452                     3447
# 2       '901430'        Ashford            1780                     3529
# 3       '902060'           Avon            6968                     4068
# 4       '902760'    Barkhamsted            1364                     4119
# ..           ...            ...             ...                      ...
# 164     '987070'  Windsor Locks            5253                     3116
# 165     '987560'        Wolcott            5880                     4430
# 166     '987700'     Woodbridge            2931                     4879
# 167     '987910'       Woodbury            4139                     4029
# 168     '988190'      Woodstock            3043                     3666
#
#      Avg. Energy Burden (% income)
# 0                                3
# ...

# %%
plt.plot(figsize=(30,20))
plt.plot(h_cost_burden[' Name'],h_cost_burden['Avg. Annual Energy Cost'])

# %%
h_cost_burden.describe()
# Out:
#        Housing Counts  Avg. Annual Energy Cost  Avg. Energy Burden (% income)
# count      169.000000               169.000000                     169.000000
# mean      8090.970414              3898.840237                       3.426036
# std       9591.212025               702.201159                       0.791794
# min        346.000000              1746.000000                       2.000000
# 25%       2038.000000              3457.000000                       3.000000
# 50%       4939.000000              3764.000000                       3.000000
# 75%       9840.000000              4219.000000                       4.000000
# max      50547.000000              6141.000000                       6.000000

# %%
h_cost_burden.head()
# Out:
#   Geography ID         Name  Housing Counts  Avg. Annual Energy Cost  \
# 0     '901080'      Andover            1235                     3700
# 1     '901220'      Ansonia            7452                     3447
# 2     '901430'      Ashford            1780                     3529
# 3     '902060'         Avon            6968                     4068
# 4     '902760'  Barkhamsted            1364                     4119
#
#    Avg. Energy Burden (% income)
# 0                              3
# 1                              5
# 2                              4
# 3                              2
# 4                              3

# %%
by_date_all.head()
# Out:
#              Town       FIPS       Year Race/Ethnicity Measure Type  \
# 400       Andover  901301080  2015-2019            All       Number
# 840       Ansonia  900901220  2015-2019            All       Number
# 1280      Ashford  901501430  2015-2019            All       Number
# 1720         Avon  900302060  2015-2019            All       Number
# 2160  Barkhamsted  900502760  2015-2019            All       Number
#
#                      Variable     Value
# 400   Median Household Income  105328.0
# 840   Median Household Income   54901.0
# 1280  Median Household Income   70952.0
# 1720  Median Household Income  131130.0
# 2160  Median Household Income  109688.0

# %%
by_date_plot = df.groupby(["Town","Race/Ethnicity"])['Value'].mean()
by_date_plot.unstack().plot(figsize=(30,10),kind='bar')
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# # Easton

# %%
easton = df['Town']=='Easton'
easton = df[easton]

# %%
non_values2 = easton[ easton['Value'] == (-9999) ].index
easton.drop(non_values2,inplace = True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
easton.describe()
# Out:
#               FIPS          Value
# count         54.0      54.000000
# mean   900123890.0  150151.000000
# std            0.0   47380.550858
# min    900123890.0   44208.000000
# 25%    900123890.0  132024.000000
# 50%    900123890.0  142586.000000
# 75%    900123890.0  157502.000000
# max    900123890.0  250001.000000

# %%
Fairfield = df['Town']=='Fairfield'
Fairfield = df[Fairfield]
non_values3 = Fairfield[ Fairfield['Value'] == (-9999) ].index
Fairfield.drop(non_values3,inplace = True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
Fairfield.describe()
# Out:
#               FIPS          Value
# count         87.0      87.000000
# mean   900126620.0  109636.367816
# std            0.0   22533.200307
# min    900126620.0   38750.000000
# 25%    900126620.0  100637.500000
# 50%    900126620.0  114531.000000
# 75%    900126620.0  122220.500000
# max    900126620.0  143453.000000

# %%
Woodbridge = df['Town']=='Fairfield'
Woodbridge = df[Woodbridge]
non_values4 = Woodbridge[ Woodbridge['Value'] == (-9999) ].index
Woodbridge.drop(non_values4,inplace = True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
Trumbull= df['Town']=='Trumbull'
Trumbull = df[Trumbull]
non_values5 = Trumbull[ Trumbull['Value'] == (-9999) ].index
Trumbull.drop(non_values5,inplace = True)

# %%
Orange= df['Town']=='Orange'
Orange = df[Orange]
non_values6 = Orange[ Orange['Value'] == (-9999) ].index
Orange.drop(non_values6,inplace = True)

# %%
North_Branford= df['Town']=='North Branford'
North_Branford = df[North_Branford]
non_values7 = North_Branford[ North_Branford['Value'] == (-9999) ].index
North_Branford.drop(non_values7,inplace = True)

# %%
Shelton= df['Town']=='Shelton'
Shelton = df[Shelton]
non_values8 = Shelton[ Shelton['Value'] == (-9999) ].index
Shelton.drop(non_values8,inplace = True)

# %%
d1=easton.append(Fairfield)
d2=d1.append(Woodbridge)
d3=d2.append(Trumbull)
d4=d3.append(Orange)
d5=d4.append(North_Branford)
d6=d5.append(Shelton)

# %%
d6_bydate= d6['Year']=='2015-2019'
d6_bydate=d6[d6_bydate]
d6_bydate
# Out:
#                  Town       FIPS       Year  \
# 21080          Easton  900123890  2015-2019
# 21088          Easton  900123890  2015-2019
# 21112          Easton  900123890  2015-2019
# 21116          Easton  900123890  2015-2019
# 22840       Fairfield  900126620  2015-2019
# 22848       Fairfield  900126620  2015-2019
# 22852       Fairfield  900126620  2015-2019
# 22856       Fairfield  900126620  2015-2019
# 22864       Fairfield  900126620  2015-2019
# 22868       Fairfield  900126620  2015-2019
# 22872       Fairfield  900126620  2015-2019
# 22876       Fairfield  900126620  2015-2019
# 22840       Fairfield  900126620  2015-2019
# 22848       Fairfield  900126620  2015-2019
# 22852       Fairfield  900126620  2015-2019
# 22856       Fairfield  900126620  2015-2019
# 22864       Fairfield  900126620  2015-2019
# 22868       Fairfield  900126620  2015-2019
# 22872       Fairfield  900126620  2015-2019
# 22876       Fairfield  900126620  2015-2019
# ...

# %%
d6_bydate.sort_values(by='Value',ascending=True)
# Out:
#                  Town       FIPS       Year  \
# 55844         Shelton  900168170  2015-2019
# 55864         Shelton  900168170  2015-2019
# 55856         Shelton  900168170  2015-2019
# 55868         Shelton  900168170  2015-2019
# 22864       Fairfield  900126620  2015-2019
# 22864       Fairfield  900126620  2015-2019
# 43996  North Branford  900953890  2015-2019
# 43960  North Branford  900953890  2015-2019
# 43992  North Branford  900953890  2015-2019
# 55872         Shelton  900168170  2015-2019
# 55840         Shelton  900168170  2015-2019
# 55876         Shelton  900168170  2015-2019
# 21088          Easton  900123890  2015-2019
# 22852       Fairfield  900126620  2015-2019
# 22852       Fairfield  900126620  2015-2019
# 22868       Fairfield  900126620  2015-2019
# 22868       Fairfield  900126620  2015-2019
# 47488          Orange  900957600  2015-2019
# 43976  North Branford  900953890  2015-2019
# 63776        Trumbull  900177200  2015-2019
# ...

# %%
town = all_df.groupby(['Town'])['Value'].mean()

# %%
## Median Household Income mean value in the towns
groups=d6_bydate.groupby(['Town'])['Value'].mean()
groups
# Out:
# Town
# Easton            143292.750000
# Fairfield         120801.000000
# North Branford     98185.250000
# Orange            120847.750000
# Shelton            78625.625000
# Trumbull          125984.285714
# Name: Value, dtype: float64

# %%
##Calculating the <60% AMI

groups*0.60
# Out:
# Town
# Easton            85975.650000
# Fairfield         72480.600000
# North Branford    58911.150000
# Orange            72508.650000
# Shelton           47175.375000
# Trumbull          75590.571429
# Name: Value, dtype: float64

# %%
##Calculating the 60%,80% AMI

(groups*0.60)+1+(groups*0.80)
# Out:
# Town
# Easton            200610.850
# Fairfield         169122.400
# North Branford    137460.350
# Orange            169187.850
# Shelton           110076.875
# Trumbull          176379.000
# Name: Value, dtype: float64

# %%
d6_bydate.groupby(['Town','Race/Ethnicity'])['Value'].mean()
# Out:
# Town            Race/Ethnicity
# Easton          All                                        157448.0
#                 Asian Alone                                100000.0
#                 White Alone                                157520.0
#                 White Alone Not Hispanic or Latino         158203.0
# Fairfield       All                                        139122.0
#                 Asian Alone                                131359.0
#                 Black or African American Alone            100313.0
#                 Hispanic or Latino                         122750.0
#                 Some Other Race Alone                       74760.0
#                 Two or More Races                          112625.0
#                 White Alone                                142026.0
#                 White Alone Not Hispanic or Latino         143453.0
# North Branford  All                                         90461.0
# ...

# %% [markdown]
# # Outage Frequency data

# %%
outages = pd.read_csv('Eversource Territory.csv')
outages
# Out:
#                  Town Zipcode              TOWN  ZIPCODE  \
# 0            ABINGTON - 06230          ABINGTON     6230
# 1              AMSTON - 06231            AMSTON     6231
# 2             ANDOVER - 06232           ANDOVER     6232
# 3             ASHFORD - 06278           ASHFORD     6278
# 4                AVON - 06001              AVON     6001
# ..                        ...               ...      ...
# 259           WOLCOTT - 06716           WOLCOTT     6716
# 260        WOODBRIDGE - 06525        WOODBRIDGE     6525
# 261          WOODBURY - 06798          WOODBURY     6798
# 262         WOODSTOCK - 06281         WOODSTOCK     6281
# 263  WOODSTOCK VALLEY - 06282  WOODSTOCK VALLEY     6282
#
#      Average Customer Duration ( Hours)  Total Duration Hours  \
# 0                                    24               31729.4
# 1                                    20              166846.9
# 2                                    24              234042.6
# ...
